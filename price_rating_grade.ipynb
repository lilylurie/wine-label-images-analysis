# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/диплом/
# Out:
# all_piemonte_wines.zip	      scaled_features_tuscany.csv  xau.zip  xay.zip	   year.txt
# num_rev_only.txt	      wine_type_only.txt	   xav.zip  xaz.zip
# num_rev.txt		      wine_type.txt		   xaw.zip  xba.zip
# scaled_features_piemonte.csv  xat.zip			   xax.zip  year_only.txt

# %%
# ! cp wine_type.txt /content/drive/MyDrive/диплом/wine_type.txt
# ! cp  year.txt  /content/drive/MyDrive/диплом/year.txt
# ! cp  num_rev.txt /content/drive/MyDrive/диплом/num_rev.txt

# %%
# !cp  /content/drive/MyDrive/диплом/* .

# %%
# ! ls

# %%
dft = pd.read_csv("image_features_tuscany.csv")
dft.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-1b78dae1fbae> in <cell line: 1>()
# ----> 1 dft = pd.read_csv("image_features_tuscany.csv")
#       2 dft.head(2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
names = dft.image_names.to_list()

# %%
len(set(names))
# Out:
# 7671

# %%
names = list(set(names))

# %%
dfp = pd.read_csv("image_features_piemonte.csv")
dfp.head(2)
# Out:
#    Unnamed: 0                   Wine  \
# 0           0  White Sushi Wine N.V.
# 1           1         Fragolino N.V.
#
#                                                 link             image_names  \
# 0  https://www.vivino.com/IT/en/umi-white-sushi-w...  WhiteSushiWineN.V..png
# 1  https://www.vivino.com/IT/en/santero-fragolino...       FragolinoN.V..png
#
#                                           image_link    temperature  \
# 0  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...   5.738831e+03
# 1  https://images.vivino.com/thumbs/fgUOE94-Tna3g...  2.584170e+189
#
#    saturation  brightness  contrast   clarity  ...  rule_of_thirds  \
# 0   89.585949  150.137468       1.0  0.064641  ...    4.263727e-07
# 1   96.286447   79.322088       1.0  0.038956  ...    6.899074e-11
#
#    colour_balance_vert  colour_balance_hor  physical_balance_vert  \
# 0         27407.775897        70753.508565               7.012457
# 1         13100.455965       108044.819368              17.422752
#
# ...

# %%
# !unzip all_piemonte_wines.zip
# Out:
# Archive:  all_piemonte_wines.zip
#   inflating: all_piemonte_wines.csv

# %%
dfp_rev = pd.read_csv("all_piemonte_wines.csv", sep=";")
dfp_rev.head(2)
# Out:
# <ipython-input-5-98a47ff30e59>:1: DtypeWarning: Columns (10,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfp_rev = pd.read_csv("all_piemonte_wines.csv", sep=";")
#   Winery                   Wine  Rating  num_review Wine type     Wine region  \
# 0    Umi  White Sushi Wine N.V.     3.3          86     White  Italy Piemonte
# 1    Umi  White Sushi Wine N.V.     3.3          86     White  Italy Piemonte
#
#   Country                  Grape  price  \
# 0      it  Sangiovese Chardonnay   3.25
# 1      it  Sangiovese Chardonnay   3.25
#
#                                                 link  ...  Wine ID  \
# 0  https://www.vivino.com/IT/en/umi-white-sushi-w...  ...  3830847
# 1  https://www.vivino.com/IT/en/umi-white-sushi-w...  ...  3830847
#
#    User's Grade                 CreatedAt  user id  followers following  \
# 0           3.5  2017-06-21T12:19:09.000Z  2226059         13        22
# ...

# %%
names_p = dfp.image_names.to_list()

# %%
subdf = dfp_rev[dfp_rev["image_name"] == "images/WhiteSushiWineN.V..png"][["Rating", "User's Grade", "price"]]
# Out:
# 3.2952380952380955

# %%
price = []
rating = []
grade = []
count = 0
for name in names_p:
  subdf = dfp_rev[dfp_rev["image_name"] == "images/" + name][["Rating", "User's Grade", "price"]]
  rating.append(subdf.Rating.to_list()[0])
  grade.append(subdf["User's Grade"].mean())
  price.append(subdf.price.to_list()[0])
  if count % 100 == 0:
    print(count)
  count += 1
len(rating)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 5933

# %%
dfp["price"] = price
dfp["rating"] = rating
dfp["grade_avg"] = grade
dfp.head(10)
# Out:
#                                                 Wine  \
# 0                              White Sushi Wine N.V.
# 1                                     Fragolino N.V.
# 2                        Il Sendallo Chardonnay 2022
# 3               Buon Paggio Grignolino Piemonte 2022
# 4               Contrada Maestra Barbera d'Asti 2022
# 5                                       Barbera 2022
# 6                                      Dolcetto 2022
# 7                  Prima Mossa Barbera Piemonte 2022
# 8        Capitano del Palio Dolcetto Monferrato 2022
# 9  Corsiero Biondo Cortese dell'Alto Monferrato 2022
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1  https://www.vivino.com/IT/en/santero-fragolino...
# 2  https://www.vivino.com/IT/en/cantine-povero-as...
# 3  https://www.vivino.com/IT/en/cantine-povero-as...
# 4  https://www.vivino.com/IT/en/cantine-povero-as...
# 5  https://www.vivino.com/IT/en/noi-vignaioli-pie...
# ...

# %%
count = (dfp['grade_avg'] == 0).sum()
count
# Out:
# 0

# %%
dfp.to_csv("image_features_piemonte.csv")

# %%
# !unzip wines_with_reviews_and_images
# Out:
# Archive:  wines_with_reviews_and_images.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of wines_with_reviews_and_images or
#         wines_with_reviews_and_images.zip, and cannot find wines_with_reviews_and_images.ZIP, period.

# %%
# !unzip xaa.zip
# !unzip xab.zip
# !unzip xac.zip
# !unzip xad.zip
# !unzip xae.zip
# !unzip xaf.zip
# !unzip xag.zip
# !unzip xah.zip
# Out:
# Archive:  xaa.zip
#   inflating: xaa.csv
# Archive:  xab.zip
#   inflating: xab.csv
# Archive:  xac.zip
#   inflating: xac.csv
# Archive:  xad.zip
#   inflating: xad.csv
# Archive:  xae.zip
#   inflating: xae.csv
# Archive:  xaf.zip
#   inflating: xaf.csv
# Archive:  xag.zip
#   inflating: xag.csv
# Archive:  xah.zip
#   inflating: xah.csv

# %%
dft1_rev = pd.read_csv("xaa.csv", sep=";")
# Out:
# <ipython-input-26-7d58459d7b84>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft1_rev = pd.read_csv("xaa.csv", sep=";")

# %%
dft1_rev = pd.read_csv("xaa.csv", sep=";")
dft2_rev = pd.read_csv("xab.csv", sep=";")
dft3_rev = pd.read_csv("xac.csv", sep=";")
dft4_rev = pd.read_csv("xad.csv", sep=";")
dft5_rev = pd.read_csv("xae.csv", sep=";")
dft6_rev = pd.read_csv("xaf.csv", sep=";")
# dft9_rev = pd.read_csv("xap.csv", sep=";")
dft7_rev = pd.read_csv("xag.csv", sep=";")
dft8_rev = pd.read_csv("xah.csv", sep=";")
# # dft9_rev = pd.read_csv("xap.csv", sep=";")
# dft10_rev = pd.read_csv("xay.csv", sep=";")
# dft11_rev = pd.read_csv("xaz.csv", sep=";")
# dft12_rev = pd.read_csv("xba.csv", sep=";")
# Out:
# <ipython-input-190-d6df5a40c747>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft1_rev = pd.read_csv("xaa.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:2: DtypeWarning: Columns (10,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft2_rev = pd.read_csv("xab.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:3: DtypeWarning: Columns (16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft3_rev = pd.read_csv("xac.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft4_rev = pd.read_csv("xad.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:6: DtypeWarning: Columns (16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft6_rev = pd.read_csv("xaf.csv", sep=";")
# ...

# %%
dft8_rev.tail(2)
# Out:
#          Winery          Wine  Rating  num_review Wine type     Wine region  \
# 731840  Argiano  Solengo 2017     4.3         559       Red  Italië Toscane
# 731841  Argiano  Solengo 2017     4.3         559       Red  Italië Toscane
#
#        Country              Grape  price  \
# 731840      it  Sangiovese Merlot   82.9
# 731841      it  Sangiovese Merlot   82.9
#
#                                                      link  ... User's Grade  \
# 731840  https://www.vivino.com/IT/en/argiano-solengo-2...  ...          1.5
# 731841  https://www.vivino.com/IT/en/argiano-solengo-2...  ...          4.0
#
#                                                      Note  \
# 731840  Underlig animalsk duft. Kroppen var ekstrem bi...
# 731841  Robust and well balanced. Dominated by the cab...
#
#                        CreatedAt     user id followers  following  \
# 731840  2014-09-29T10:24:46.000Z     53658.0     116.0       36.0
# ...

# %%
dft_rev_5 = pd.read_csv("xaj.csv", sep=";")

# %%
img_nms = dft_rev_5.Wine.to_list()

# %%
for i in range(len(img_nms)):
  img_nms[i] = img_nms[i].replace(" ", "") + ".png"

# %%
img_nms[1]
# Out:
# 'BrunellodiMontalcino2013.png'

# %%
dft1_rev = dft1_rev[dft1_rev["image_name"] == "images/Toscana2019.png"]

# %% [markdown]
# BrunellodiMontalcino2017.png

# %%
dft1_rev.head(1)
# Out:
#      Winery          Wine  Rating  num_review Wine type    Wine region  \
# 0  La Massa  Toscana 2019     4.0       324.0       Red  Italy Toscana
#
#   Country              Grape  price  \
# 0      it  Sangiovese Merlot   19.5
#
#                                                 link  ... User's Grade  \
# 0  https://www.vivino.com/IT/en/fattoria-la-massa...  ...          4.0
#
#                                                Note                 CreatedAt  \
# 0  Fruité, tanins fondus, belle longueur en bouche   2021-02-03T19:06:15.000Z
#
#       user id followers  following  User Ratings  language  \
# 0  41949624.0       0.0        0.0           2.0        fr
#
#                             label              image_name
# 0  fattoria-la-massa-toscana-2016  images/Toscana2019.png
#
# [1 rows x 22 columns]

# %%
frames1 = [dft1_rev[dft1_rev["image_name"] != "images/Toscana2019.png"],dft2_rev, dft3_rev,dft4_rev]#, dft5_rev]#, dft6_rev, dft7_rev,dft8_rev,dft9_rev[dft9_rev["image_name"]] != "images/Nemorino2020.png"]

dft_rev1 = pd.concat(frames1)
frames2 = [dft5_rev, dft6_rev,dft7_rev, dft8_rev]
dft_rev2 = pd.concat(frames2)
# # frames3 = [dft10_rev, dft11_rev, dft12_rev]
# # dft_rev3 = pd.concat(frames3)
frames = [dft_rev1, dft_rev2]#, dft_rev3]
dft_rev_1 = pd.concat(frames)

# %%
dft_rev_4.shape
# Out:
# (3529170, 22)

# %%
del dft_rev_2

# %%
import gc

# %%
gc.collect()
# Out:
# 0

# %%
dft1_rev = dft1_rev[["image_name","num_review", "Wine type", "Year", "followers", "following", "User Ratings"]]
dft1_rev.head(2)
# Out:
#                image_name  num_review Wine type  Year  followers  following  \
# 0  images/Toscana2019.png       324.0       Red  2019        0.0        0.0
# 1  images/Toscana2019.png       324.0       Red  2019        0.0        0.0
#
#    User Ratings
# 0           2.0
# 1           1.0

# %%
frames = [dft_rev_11, dft1_rev]#, dft_rev3]
dft_rev_12 = pd.concat(frames)

# %%
# dft_rev_5["image_name"] = img_nms
dft_rev_12.head(1)
# Out:
#                      image_name  num_review Wine type  Year followers  \
# 0  images/BolgheriRosso1998.png        21.0       Red  1998       1.0
#
#   following User Ratings
# 0       0.0        220.0

# %%
dft9_rev.tail(2)
# Out:
#                   Winery           Wine  Rating  num_review Wine type  \
# 746628  I Giusti & Zanza  Nemorino 2020     0.0        11.0       Red
# 746629  I Giusti & Zanza  Nemorino 2020     0.0        11.0       Red
#
#           Wine region Country              Grape  price  \
# 746628  Italy Toscana      it  Sangiovese Merlot   12.2
# 746629  Italy Toscana      it  Sangiovese Merlot   12.2
#
#                                                      link  ... User's Grade  \
# 746628  https://www.vivino.com/IT/en/i-giusti-and-zanz...  ...          3.0
# 746629  https://www.vivino.com/IT/en/i-giusti-and-zanz...  ...          4.0
#
#                                                      Note  \
# 746628  Bouquet muito bom, não se percebe o álcool. Ta...
# 746629                                          Excellent
#
#                        CreatedAt    user id followers  following  \
# 746628  2014-10-13T01:15:57.000Z   547976.0     141.0       75.0
# ...

# %%
dft_rev2 = dft_rev2.drop(["Note"], axis=1)
dft_rev2.head(1)
# Out:
#     Winery                                    Wine  Rating  num_review  \
# 0  Duemani  Altrovino Merlot - Cabernet Franc 2014     4.0         212
#
#   Wine type          Wine region Country              Grape  price  \
# 0       Red  Italie Côte toscane      it  Sangiovese Merlot   38.5
#
#                                                 link  ...  Wine ID  \
# 0  https://www.vivino.com/IT/en/duemani-altrovino...  ...  1101036
#
#    User's Grade                 CreatedAt    user id  followers following  \
# 0           3.0  2015-03-20T01:02:59.000Z  4130340.0        0.0       0.0
#
#   User Ratings language                                         label  \
# 0          2.0       en  duemani-altrovino-merlot-cabernet-franc-2000
#
#                                      image_name
# 0  images/AltrovinoMerlot-CabernetFranc2014.png
#
# [1 rows x 21 columns]

# %%
frames = [dft_rev1, dft_rev2]

dft_rev_1 = pd.concat(frames)

# %%
dft_rev_1.shape
# Out:
# (5867195, 21)

# %%
dft_rev_1.tail(1)
# Out:
#          Winery          Wine  Rating  num_review Wine type     Wine region  \
# 731841  Argiano  Solengo 2017     4.3       559.0       Red  Italië Toscane
#
#        Country              Grape  price  \
# 731841      it  Sangiovese Merlot   82.9
#
#                                                      link  ... Wine ID  \
# 731841  https://www.vivino.com/IT/en/argiano-solengo-2...  ...  2887.0
#
#         User's Grade                 CreatedAt     user id  followers  \
# 731841           4.0  2021-01-30T14:55:09.000Z  27271834.0        1.0
#
#        following User Ratings language                 label  \
# 731841       0.0         19.0       en  argiano-solengo-1998
#
#                     image_name
# 731841  images/Solengo2017.png
#
# [1 rows x 21 columns]

# %%
rating= []
subdf = dfp_rev[dfp_rev["image_name"] == "images/AltrovinoMerlot-CabernetFranc2014.png"][["Rating", "User's Grade", "price"]]
subdf
# Out:
# Empty DataFrame
# Columns: [Rating, User's Grade, price]
# Index: []

# %%
subdf = dfp_rev_1[dfp_rev["image_name"] == "images/BolgheriRosso1998.png"][["Rating", "User's Grade", "price"]]
subdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-d37f9e0a550f> in <cell line: 1>()
# ----> 1 subdf = dfp_rev_1[dfp_rev["image_name"] == "images/BolgheriRosso1998.png"][["Rating", "User's Grade", "price"]]
#       2 subdf
#
# NameError: name 'dfp_rev_1' is not defined

# %% [markdown]
# Solengo2017.png

# %%
price = []
rating = []
grade = []
count = 0
for i in range(len(names)):
  if count % 100 == 0:
    print(count)
  count += 1
  subdf = dft_rev_5[dft_rev_5["image_name"] == names[i]]
  if subdf.shape[0] == 0:
    continue
  rating.append((names[i],subdf.Rating.to_list()[0]))
  grade.append((names[i],subdf["User's Grade"].mean()))
  price.append((names[i],subdf.price.to_list()[0]))
len(rating)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 476

# %%
pr1 = price
rat1 = rating
gr1 = grade

# %%
f = open("pr3.txt", "w")
for p in pr1:
  f.write(p[0])
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
f = open("rat3.txt", "w")
for p in rat1:
  f.write(p[0])
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
f = open("gr3 .txt", "w")
for p in gr1:
  f.write(p[0])
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
file1 = open("rat.txt", "r+")
for_rating = file1.readlines()
file1.close()
len(for_rating)
# Out:
# 12416

# %%
rat_names = []
rat_ratings = []
for i in range(len(for_rating)):
  if i % 2 == 0:
    rat_names.append(for_rating[i])
  else:
    rat_ratings.append(float(for_rating[i]))
len(rat_ratings)
# Out:
# 6208

# %%
pr_prices0[0:2]
# Out:
# [10.38, 80.0]

# %%
len(pr_names)
# Out:
# 6208

# %%
file1 = open("/content/rat2.txt", "r+")
for_rating = file1.readlines()
file1.close()
len(for_rating)
# Out:
# 3782

# %%
for i in range(len(for_rating)):
  if i % 2 == 0:
    rat_names.append(for_rating[i])
  else:
    rat_ratings.append(float(for_rating[i]))
len(rat_ratings)
# Out:
# 9722

# %%
len(pr_names)
# Out:
# 9722

# %%
gr_names.pop(-1)
# Out:
# 'a\n'

# %%
len(gr_names)
# Out:
# 7831

# %% [markdown]
# ```pr_names, pr_prices0, gr_names, gr_grades```

# %%
if pr_names == rat_names:
  print("Yes")
else:
  print("no")
# Out:
# Yes

# %%
count = 0
for i in range(len(names)):
  if count % 100 == 0:
    print(count)
  count += 1
  subdf = dft_rev_3[dft_rev_3["image_name"] == "images/" + names[i]]
  if subdf.shape[0] == 0:
    continue
  rating.append((names[i],subdf.Rating.to_list()[0]))
  grade.append((names[i],subdf["User's Grade"].mean()))
  price.append((names[i],subdf.price.to_list()[0]))
len(rating)
# Out:
# 0

# %%
pr2 = price
rat2 = rating
gr2 = grade

# %%
f = open("pr.txt", "w")
for p in pr2:
  f.write(p[0])
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
f = open("rat.txt", "w")
for p in rat2:
  f.write(p[0])
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
f = open("gr.txt", "w")
for p in gr2:
  f.write(p[0])
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
[y[0] for y in tuple_list].index('kumquat')

# %%
rating[:10]
# Out:
# [('BolgheriRosso1998.png', 0.0),
#  ('BrunellodiMontalcinoRiserva2010.png', 4.7),
#  ("TenutaTignanello'Solaia'2006.png", 4.7),
#  ("TenutaTignanello'Solaia'1997.png", 4.7),
#  ('BrunellodiMontalcino2006.png', 4.6),
#  ('CerretaltoBrunellodiMontalcino2007.png', 4.6),
#  ('RiservaDucaleOroChiantiClassico(GranSelezioneGold)1980.png', 0.0),
#  ('BrunellodiMontalcino2018.png', 0.0),
#  ('SchidionelllMillennio1997.png', 0.0),
#  ('MigliaraSyrah2006.png', 4.1)]

# %%
len(set(price))
# Out:
# 3784

# %%
names = dft.image_names.to_list()

# %%
names = list(set(names))

# %%
len(names)
# Out:
# 7671

# %% [markdown]
# images/Nemorino2020.png

# %%
price[2952:2954]
# Out:
# [('LeonardodaVinciBrunellodiMontalcino2011.png', 32.5),
#  ('RossodiMontepulciano2007.png', 10.5)]

# %%
grade.append(('SangiovetodiToscana2004.png', 4.0607476635514015))

# %%
del grade[2953]
pr2[2952:2954]
# Out:
# [('LeonardodaVinciBrunellodiMontalcino2011.png', 32.5),
#  ('RossodiMontepulciano2007.png', 10.5)]

# %%
pr_names[9721]
# Out:
# 'MontesodiToscana1998.png\n'

# %%
dft.image_names[5448]
# Out:
# "Ca'MarcandaBolgheri2015.png"

# %%
pr_for_df = []
gr_for_df = []
rat_for_df =[]
for ind in range(0, len(names)):
  i = pr_names.index(names[ind] + "\n")
  pr_for_df.append(pr_prices0[i])
  gr_for_df.append(gr_grades[i])
  rat_for_df.append(rat_ratings[i])
len(rat_for_df)
# Out:
# 10394

# %%
dft["price"] = pr_for_df
dft["rating"] = rat_for_df
dft["grade_avg"] = gr_for_df
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names    temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png   8.665253e+22   72.145970  101.875833
# 1  BrunellodiMontalcinoRiserva2010.png  5.296501e+121   74.638879   83.735040
#
#    contrast   clarity  colorfulness  ...  rule_of_thirds  colour_balance_vert  \
# 0       1.0  0.105306     22.690002  ...    1.422962e-09         28628.411530
# 1       1.0  0.072747     27.365681  ...    4.251168e-07         10180.439444
#
# ...

# %%
dft.to_csv("image_features_tuscany.csv", index=False)

# %%
len(rat_for_df)
# Out:
# 10

# %%
pr_for_df.append(120.63)

# %%
len(pr_names)
# Out:
# 10198

# %%
pr_for_df
# Out:
# [724.5,
#  800.0,
#  560.0,
#  599.9,
#  864.0,
#  680.0,
#  1100.0,
#  829.74,
#  1490.0,
#  5980.0,
#  1100.0,
#  7000.0,
#  1035.0,
#  58.6,
#  56.8,
#  59.0,
#  55.0,
#  59.0,
#  58.0,
#  59.0,
#  59.65,
#  59.0,
#  54.85,
#  58.45,
#  82.4,
#  58.0,
#  65.0,
#  78.0,
#  60.0,
#  58.5,
#  60.0,
#  69.03,
#  63.25,
#  54.8,
#  65.99,
#  57.0,
#  77.0,
#  55.0,
#  55.0,
#  54.0,
#  55.0,
#  800.0,
#  57.1,
#  54.99,
#  54.0,
#  55.5,
#  59.4,
#  74.1,
#  57.5,
#  72.3,
#  60.0,
#  75.0,
#  80.0,
#  73.9,
#  54.9,
#  67.0,
#  63.95,
#  57.7,
#  60.0,
#  829.74,
#  59.0,
#  57.0,
#  59.65,
#  60.0,
#  59.9,
#  59.0,
#  59.9,
#  69.0,
#  55.0,
#  58.9,
#  73.19,
#  59.0,
#  54.45,
#  60.0,
#  79.0,
#  57.0,
#  58.45,
#  58.56,
#  69.03,
#  55.0,
#  64.2,
#  60.0,
#  55.0,
#  59.65,
#  59.0,
#  56.15,
#  69.75,
#  59.9,
#  56.36,
#  63.0,
#  58.0,
#  69.9,
#  58.0,
#  60.0,
#  77.0,
#  57.0,
#  54.9,
#  800.0,
#  70.0,
#  65.0,
#  59.3,
#  60.0,
#  60.0,
#  80.0,
#  66.0,
#  69.0,
# ...

# %%
pr_names[0:1000]
# Out:
# ['Toscana2010.png\n',
#  'BrunellodiMontalcino2012.png\n',
#  'OdoardoBeccariChiantiClassicoRiserva2008.png\n',
#  'Coldipietrerosse2013.png\n',
#  'Resico2021.png\n',
#  'ToscanaFornace1999.png\n',
#  'AnticaChiusinaVinoNobilediMontepulciano2017.png\n',
#  'ChardonnayToscanaLeBruniche2022.png\n',
#  'VinSantoSerelleChianti2008.png\n',
#  'Volterrano2013.png\n',
#  'Campanaio2019.png\n',
#  'BazzicoVermentino2021.png\n',
#  'CampogiovanniBrunellodiMontalcinoRiservaIlQuercione2007.png\n',
#  'BadiaaPassignanoChiantiClassicoRiserva1999.png\n',
#  'RèmoleBianco2022.png\n',
#  'RossodiMontalcino1995.png\n',
#  'PelagrilliBrunellodiMontalcino2016.png\n',
#  'RosédiBolgheri1985.png\n',
#  'ILCorzanelloBianco2021.png\n',
#  'ObizzoVermentino2022.png\n',
#  'RetromarciaChiantiClassico2019.png\n',
#  'Toscana2021.png\n',
#  'GiovinRe2012.png\n',
#  'ConcertoDiFonterutoli2018.png\n',
#  'BrunellodiMontalcinoRiserva2011.png\n',
#  'VinoNobilediMontepulciano1978.png\n',
# ...

# %%
name = "OrenoToscana2000.png"
pr_names.index(name + "\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-1f5259f89940> in <cell line: 2>()
#       1 name = "OrenoToscana2000.png"
# ----> 2 pr_names.index(name + "\n")
#
# ValueError: 'OrenoToscana2000.png\n' is not in list

# %%
for i in range(len(pr1)):
  pr_names.append(pr1[i][0])
  pr_prices0.append(pr1[i][1])
  gr_grades.append(gr1[i][1])
  rat_ratings.append(rat1[i][1])
len(pr_names)
# Out:
# 10198

# %%
pr_names[0][-1]
# Out:
# '\n'

# %%
for i in range(len(pr_names)):
  if pr_names[i][-1] != '\n':
    pr_names[i] = pr_names[i] + '\n'

# %% [markdown]
# ## Количество отзывов, год, информация про пользователей

# %%
import pandas as pd

# %%
dft = pd.read_csv("scaled_features_tuscany.csv")

# %%
names = dft.image_names.to_list()

# %%
dfp = pd.read_csv("scaled_features_piemonte.csv")

# %%
dft_rev_12.head(1)
# Out:
#                      image_name  num_review Wine type  Year followers  \
# 0  images/BolgheriRosso1998.png        21.0       Red  1998       1.0
#
#   following User Ratings
# 0       0.0        220.0

# %%
import statistics

# %%
from tqdm import tqdm

names_for_list = []
for name in tqdm(names):
  subdf = dft_rev_1[dft_rev_1["image_name"] == "images/" + name]
  if subdf.shape[0] != 0:
    names_for_list.append(name)
# Out:
# 100%|██████████| 10394/10394 [1:47:26<00:00,  1.61it/s]

# %%
len(names_for_list)
# Out:
# 4867

# %%
file1 = open("year_only.txt", "r+")
for_num = file1.readlines()
file1.close()
len(for_num)
# Out:
# 4867

# %%
for_num[1]
# Out:
# '1607.0\n'

# %%
for_num1 = []
for n in for_num:
  for_num1.append(n[:-1])
for_num1[1]
# Out:
# '1607.0'

# %%
fn = []
for n in for_num1:
  fn.append(float(n))
len(fn)
# Out:
# 4867

# %%
second_half = list(zip(names_for_list, fn))

# %%
second_half[0]
# Out:
# ('BrunellodiMontalcinoRiserva2010.png', 92.0)

# %%
a = list(range(5))
b = list(range(10))

list(zip(a, b))
# Out:
# [(0, 0), (1, 1), (2, 2), (3, 3), (4, 4)]

# %%
num_review = []
wine_type = []
year = []
followers = []
following = []
ratings_of_user = []
count = 0
for name in names:
  if count % 100 == 0:
    print(count)
  count += 1
  subdf = dft_rev_1[dft_rev_1["image_name"] == "images/" + name]
  if subdf.shape[0] == 0:
    continue
  num_review.append((name, subdf.num_review.to_list()[0]))
  # float_list = list(map(float, subdf["followers"].to_list()))
  # followers.append(statistics.mean(float_list))
  # following.append(subdf["following"].mean())
  # float_list1 = list(map(float, subdf["following"].to_list()))
  # following.append(statistics.mean(float_list1))
  # # ratings_of_user.append(subdf["User Ratings"].mean())
  # float_list2 = list(map(float, subdf["User Ratings"].to_list()))
  # followers.append(statistics.mean(float_list2))
  wine_type.append((name,subdf["Wine type"].to_list()[0]))
  year.append((name,subdf.Year.to_list()[0]))

len(num_review)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4867

# %%
len(num_review)
# Out:
# 5446

# %%
f = open("num_rev.txt", "a")
for p in second_half:
  f.write(str(p))
  f.write("\n")
  f.write(str(p[1]))
  f.write("\n")
f.close()

# %%
f = open("wine_type.txt", "a")
for i in range(len(for_num)):
  f.write(str(second_half[i][0]))
  f.write("\n")
  f.write(str(for_num[i]))
  f.write("\n")
f.close()

# %%
f = open("year.txt", "a")
for i in range(len(for_num)):
  f.write(str(second_half[i][0]))
  f.write("\n")
  f.write(str(for_num[i]))
  f.write("\n")
f.close()

# %%
with open("wine_type.txt", "r") as f:
  lines = f.readlines()
  result = [line for line in lines if line != '\n']

# %%
with open("wine_type.txt", "w") as f:
  for line in result:
    f.write(line)

# %%
result[-10:]
# Out:
# ['BrunellodiMontalcino1986.png\n',
#  '1986\n',
#  'BrunellodiMontalcinoRiserva2004.png\n',
#  '2004\n',
#  'BrunellodiMontalcinoRiserva2007.png\n',
#  '2007\n',
#  'BrunellodiMontalcino2001.png\n',
#  '2001\n',
#  'MassimoBrunellodiMontalcinoRiserva2015.png\n',
#  '2015\n']

# %%
names[5446]
# Out:
# 'Brendino2016.png'

# %%
names[5445]
# Out:
# 'BrunellodiMontalcino2013.png'

# %%
count = 0
for i in range(5446,len(names)):
  if count % 100 == 0:
    print(count)
  count += 1
  subdf = dft_rev_1[dft_rev_1["image_name"] == "images/" + names[i]]
  if subdf.shape[0] == 0:
    continue
  num_review.append(subdf.num_review.to_list()[0])
  # float_list = list(map(float, subdf["followers"].to_list()))
  # followers.append(statistics.mean(float_list))
  # following.append(subdf["following"].mean())
  # float_list1 = list(map(float, subdf["following"].to_list()))
  # following.append(statistics.mean(float_list1))
  # # ratings_of_user.append(subdf["User Ratings"].mean())
  # float_list2 = list(map(float, subdf["User Ratings"].to_list()))
  # followers.append(statistics.mean(float_list2))
  wine_type.append(subdf["Wine type"].to_list()[0])
  year.append(subdf.Year.to_list()[0])
  # subdf = dft_rev_1[dft_rev_1["image_name"] == names[i]]
  # if subdf.shape[0] == 0:
  #   continue

len(year)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8967cbdc1c74> in <cell line: 2>()
#       4     print(count)
#       5   count += 1
# ----> 6   subdf = dft_rev_1[dft_rev_1["image_name"] == "images/" + name]
#       7   if subdf.shape[0] == 0:
#       8     continue
#
# NameError: name 'name' is not defined

# %%
num1 = []
year1 = []
wine_type1 = []
for i in range(len(num_review)):
  num1.append((names[i],num_review[i]))
  year1.append((names[i],year[i]))
  wine_type1.append((names[i], wine_type[i]))

# %%
len(year1)
# Out:
# 5446

# %%
num_review = num1
year = year1
wine_type = wine_type1

# %%
file1 = open("num_rev.txt", "r+")
for_num = file1.readlines()
file1.close()
len(for_num)
# Out:
# 12416

# %%
num_review = []
rat_ratings = []
for i in range(len(for_rating)):
  if i % 2 == 0:
    rat_names.append(for_rating[i])
  else:
    rat_ratings.append(float(for_rating[i]))
len(rat_ratings)
# Out:
# 6208

# %% [markdown]
# ### Перенос из текстовых файлов в датасет

# %%
file1 = open("num_rev.txt", "r+")
for_rating = file1.readlines()
file1.close()
len(for_rating)
# Out:
# 20626

# %%
ex_names = []
numbers = []
for i in range(len(for_rating)):
  if i % 2 == 0:
    ex_names.append(for_rating[i])
  else:
    numbers.append(for_rating[i])
len(numbers)
# Out:
# 10313

# %%
ex_names[0]
# Out:
# 'BolgheriRosso1998.png\n'

# %%
ex_names1 = []
for ex_name in ex_names:
  ex_names1.append(ex_name[:-1])
ex_names = ex_names1
ex_names[0]
# Out:
# 'BolgheriRosso1998.png'

# %%
numbers[0]
# Out:
# '21.0\n'

# %%
nums1 = []
for ex_name in numbers:
  nums1.append(float(ex_name[:-1]))
numbers = nums1
numbers[0]
# Out:
# 21.0

# %%
len(numbers)
# Out:
# 10313

# %%
ex_names.index('BolgheriRosso1998.png')
# Out:
# 0

# %%
names[10000]
# Out:
# "d'Alceo2005.png"

# %%
ordered_numbers = []
for name in names:
  # ordered_numbers.append(numbers[ex_names.index(name)])
  ordered_numbers.append(numbers[ex_names.index(name)] if name in ex_names else 0)

# %%
len(ordered_numbers)
# Out:
# 10394

# %%
dft["num_review"] = ordered_numbers
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_Rakkas-Regular  \
# 0  0.266658  0.646820     -0.679265  ...                      0
# 1  0.266658  0.065375     -0.382915  ...                      0
#
#    font_2_RobotoMono-Regular  font_2_RobotoSlab-Regular  font_2_Rubik-Regular  \
# ...

# %%
file1 = open("wine_type.txt", "r+")
for_rating = file1.readlines()
file1.close()
len(for_rating)
# Out:
# 20626

# %%
wtypes = []
for i in range(len(for_rating)):
  if i % 2 != 0:
    wtypes.append(for_rating[i])
len(wtypes)
# Out:
# 10313

# %%
wtypes[0]
# Out:
# 'Red\n'

# %%
wtypes1 = []
for wtype in wtypes:
  wtypes1.append(wtype[:-1])
wtypes = wtypes1
wtypes[0]
# Out:
# 'Red'

# %%
numbers[0]
# Out:
# '21.0\n'

# %%
nums1 = []
for ex_name in numbers:
  nums1.append(float(ex_name[:-1]))
numbers = nums1
numbers[0]
# Out:
# 21.0

# %%
len(numbers)
# Out:
# 10313

# %%
ex_names.index('BolgheriRosso1998.png')
# Out:
# 0

# %%
names[10000]
# Out:
# "d'Alceo2005.png"

# %%
ordered_types = []
for name in names:
  # ordered_numbers.append(numbers[ex_names.index(name)])
  ordered_types.append(wtypes[ex_names.index(name)] if name in ex_names else 'Red')

# %%
len(ordered_types)
# Out:
# 10394

# %%
len(set(ordered_types))
# Out:
# 5

# %%
dft["wine_type"] = ordered_types
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_RobotoMono-Regular  \
# 0  0.266658  0.646820     -0.679265  ...                          0
# 1  0.266658  0.065375     -0.382915  ...                          0
#
# ...

# %%
dft1 = pd.get_dummies(dft.wine_type, prefix='wine_type')
print(dft1.head(3))
# Out:
#    wine_type_Dessert  wine_type_Red  wine_type_Rose  wine_type_Sparkling  \
# 0              False           True           False                False
# 1              False           True           False                False
# 2              False           True           False                False
#
#    wine_type_White
# 0            False
# 1            False
# 2            False

# %%
dft["wine_type_Dessert"] = dft1.wine_type_Dessert
dft["wine_type_Red"] = dft1.wine_type_Red
dft["wine_type_Rose"] = dft1.wine_type_Rose
dft["wine_type_Sparkling"] = dft1.wine_type_Sparkling
dft["wine_type_White"] = dft1.wine_type_White
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_Times New Roman  \
# 0  0.266658  0.646820     -0.679265  ...                       0
# 1  0.266658  0.065375     -0.382915  ...                       0
#
#    font_2_Times New Roman Italic  font_2_Verdana Italic  num_review  \
# ...

# %%
dft = dft.drop(columns=['wine_type'])
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_Tahoma Bold  \
# 0  0.266658  0.646820     -0.679265  ...                   0
# 1  0.266658  0.065375     -0.382915  ...                   0
#
#    font_2_Times New Roman  font_2_Times New Roman Italic  \
# ...

# %%
dft["wine_type_Dessert"] = dft["wine_type_Dessert"].astype(int)
dft["wine_type_Red"] = dft["wine_type_Red"].astype(int)
dft["wine_type_Rose"] = dft["wine_type_Rose"].astype(int)
dft["wine_type_Sparkling"] = dft["wine_type_Sparkling"].astype(int)
dft["wine_type_White"] = dft["wine_type_White"].astype(int)
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_Tahoma Bold  \
# 0  0.266658  0.646820     -0.679265  ...                   0
# 1  0.266658  0.065375     -0.382915  ...                   0
#
#    font_2_Times New Roman  font_2_Times New Roman Italic  \
# ...

# %%
dft.to_csv('scaled_features_tuscany.csv', index=False)

# %%
! cp scaled_features_tuscany.csv /content/drive/MyDrive/диплом/scaled_features_tuscany.csv

# %%
file1 = open("year.txt", "r+")
for_rating = file1.readlines()
file1.close()
len(for_rating)
# Out:
# 20626

# %%
years = []
for i in range(len(for_rating)):
  if i % 2 != 0:
    years.append(for_rating[i])
len(years)
# Out:
# 10313

# %%
years[0]
# Out:
# '1998\n'

# %%
years1 = []
for year in years:
  years1.append(int(year[:-1]) if year[:-1] != 'N.V.' else 2024)
years = years1
years[0]
# Out:
# 1998

# %%
numbers[0]
# Out:
# '21.0\n'

# %%
nums1 = []
for ex_name in numbers:
  nums1.append(float(ex_name[:-1]))
numbers = nums1
numbers[0]
# Out:
# 21.0

# %%
len(numbers)
# Out:
# 10313

# %%
ex_names.index('BolgheriRosso1998.png')
# Out:
# 0

# %%
names[10000]
# Out:
# "d'Alceo2005.png"

# %%
ordered_years = []
count = 0
for name in names:
  # ordered_numbers.append(numbers[ex_names.index(name)])
  if name in ex_names:
    ordered_years.append(years[ex_names.index(name)])
    count += 1
  else:
    ordered_years.append(int('2024'))
    count += 1
count
# Out:
# 10394

# %%
len(ordered_years)
# Out:
# 10394

# %%
len(names)
# Out:
# 10394

# %%
min(ordered_years)
# Out:
# 1945

# %%
for i in range(len(ordered_years)):
  ordered_years[i] -= 1945
ordered_years[0]
# Out:
# 53

# %%
amin, amax = min(ordered_years), max(ordered_years)
for i, val in enumerate(ordered_years):
  ordered_years[i] = (val-amin) / (amax-amin)
ordered_years[0]
# Out:
# 0.6708860759493671

# %%
len(ordered_types)
# Out:
# 10394

# %%
len(set(ordered_types))
# Out:
# 5

# %%
dft["year"] = ordered_years
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_Times New Roman  \
# 0  0.266658  0.646820     -0.679265  ...                       0
# 1  0.266658  0.065375     -0.382915  ...                       0
#
#    font_2_Times New Roman Italic  font_2_Verdana Italic  num_review  \
# ...

# %%
dft.head(2)
# Out:
#                                   Wine  \
# 0                  Bolgheri Rosso 1998
# 1  Brunello di Montalcino Riserva 2010
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
#
#                                           image_link  \
# 0  https://images.vivino.com/thumbs/vqcwf45nRNaD4...
# 1  https://images.vivino.com/thumbs/LQwoyH7QSIa3j...
#
#                            image_names  temperature  saturation  brightness  \
# 0                BolgheriRosso1998.png     1.750861    0.250517    0.121760
# 1  BrunellodiMontalcinoRiserva2010.png     1.750861    0.346001   -0.531521
#
#    contrast   clarity  colorfulness  ...  font_2_Times New Roman  \
# 0  0.266658  0.646820     -0.679265  ...                       0
# 1  0.266658  0.065375     -0.382915  ...                       0
#
#    font_2_Times New Roman Italic  font_2_Verdana Italic  num_review  \
# ...

# %%
num_rev = dft.num_review.to_list()

# %%
num_rev[0]
# Out:
# 21.0

# %%
amin, amax = min(num_rev), max(num_rev)
for i, val in enumerate(num_rev):
  num_rev[i] = (val-amin) / (amax-amin)
num_rev[0]
# Out:
# 0.0003105819714560379

# %%
dft["num_review"] = num_rev

# %%
dft.to_csv('scaled_features_tuscany.csv', index=False)

# %%
! cp scaled_features_tuscany.csv /content/drive/MyDrive/диплом/scaled_features_tuscany.csv

# %%
# !unzip xaa.zip
# !unzip xab.zip
# !unzip xac.zip
# !unzip xad.zip
# !unzip xae.zip
# !unzip xaf.zip
# !unzip xag.zip
# !unzip xah.zip
# Out:
# Archive:  xaa.zip
#   inflating: xaa.csv
# Archive:  xab.zip
#   inflating: xab.csv
# Archive:  xac.zip
#   inflating: xac.csv
# Archive:  xad.zip
#   inflating: xad.csv
# Archive:  xae.zip
#   inflating: xae.csv
# Archive:  xaf.zip
#   inflating: xaf.csv
# Archive:  xag.zip
#   inflating: xag.csv
# Archive:  xah.zip
#   inflating: xah.csv

# %%
dft1_rev = pd.read_csv("xaa.csv", sep=";")
# Out:
# <ipython-input-26-7d58459d7b84>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft1_rev = pd.read_csv("xaa.csv", sep=";")

# %%
dft1_rev = pd.read_csv("xaa.csv", sep=";")
dft2_rev = pd.read_csv("xab.csv", sep=";")
dft3_rev = pd.read_csv("xac.csv", sep=";")
dft4_rev = pd.read_csv("xad.csv", sep=";")
dft5_rev = pd.read_csv("xae.csv", sep=";")
dft6_rev = pd.read_csv("xaf.csv", sep=";")
# dft9_rev = pd.read_csv("xap.csv", sep=";")
dft7_rev = pd.read_csv("xag.csv", sep=";")
dft8_rev = pd.read_csv("xah.csv", sep=";")
# # dft9_rev = pd.read_csv("xap.csv", sep=";")
# dft10_rev = pd.read_csv("xay.csv", sep=";")
# dft11_rev = pd.read_csv("xaz.csv", sep=";")
# dft12_rev = pd.read_csv("xba.csv", sep=";")
# Out:
# <ipython-input-190-d6df5a40c747>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft1_rev = pd.read_csv("xaa.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:2: DtypeWarning: Columns (10,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft2_rev = pd.read_csv("xab.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:3: DtypeWarning: Columns (16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft3_rev = pd.read_csv("xac.csv", sep=";")
# <ipython-input-190-d6df5a40c747>:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft4_rev = pd.read_csv("xad.csv", sep=";")

# %%
dft8_rev.tail(2)
# Out:
#          Winery          Wine  Rating  num_review Wine type     Wine region  \
# 731840  Argiano  Solengo 2017     4.3         559       Red  Italië Toscane
# 731841  Argiano  Solengo 2017     4.3         559       Red  Italië Toscane
#
#        Country              Grape  price  \
# 731840      it  Sangiovese Merlot   82.9
# 731841      it  Sangiovese Merlot   82.9
#
#                                                      link  ... User's Grade  \
# 731840  https://www.vivino.com/IT/en/argiano-solengo-2...  ...          1.5
# 731841  https://www.vivino.com/IT/en/argiano-solengo-2...  ...          4.0
#
#                                                      Note  \
# 731840  Underlig animalsk duft. Kroppen var ekstrem bi...
# 731841  Robust and well balanced. Dominated by the cab...
#
#                        CreatedAt     user id followers  following  \
# 731840  2014-09-29T10:24:46.000Z     53658.0     116.0       36.0
# ...

# %%
frames1 = [dft1_rev,dft2_rev, dft3_rev,dft4_rev]#, dft5_rev]#, dft6_rev, dft7_rev,dft8_rev,dft9_rev[dft9_rev["image_name"]] != "images/Nemorino2020.png"]

dft_rev1 = pd.concat(frames1)
frames2 = [dft5_rev, dft6_rev,dft7_rev, dft8_rev[dft8_rev["image_name"] != "images/Solengo2017.png"]]
dft_rev2 = pd.concat(frames2)
# # frames3 = [dft10_rev, dft11_rev, dft12_rev]
# # dft_rev3 = pd.concat(frames3)
frames = [dft_rev1, dft_rev2]#, dft_rev3]
dft_rev_1 = pd.concat(frames)

# %%
dft_rev_1.head(2)
# Out:
#          Winery                 Wine  Rating  num_review Wine type  \
# 0  Le Macchiole  Bolgheri Rosso 1998     0.0        21.0       Red
# 1  Le Macchiole  Bolgheri Rosso 1998     0.0        21.0       Red
#
#       Wine region Country                  Grape  price  \
# 0  Italy Bolgheri      it  Sangiovese Chardonnay  724.5
# 1  Italy Bolgheri      it  Sangiovese Chardonnay  724.5
#
#                                                 link  ... User's Grade  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...  ...          4.0
# 1  https://www.vivino.com/IT/en/le-macchiole-bolg...  ...          4.5
#
#                                                 Note  \
# 0                    Good aroma. Highly recommended.
# 1  Peppery and earthy nose. Tropical fruit with h...
#
#                   CreatedAt     user id followers  following User Ratings  \
# 0  2016-10-09T09:21:07.000Z  11789578.0       1.0        0.0        220.0
# ...

# %%
dft_rev_1 = dft_rev_1[["followers", "following", "User Ratings", "image_name"]]
dft_rev_1.head(2)
# Out:
#   followers following User Ratings                    image_name
# 0       1.0       0.0        220.0  images/BolgheriRosso1998.png
# 1       2.0       3.0        183.0  images/BolgheriRosso1998.png

# %%
names[1]
# Out:
# 'BrunellodiMontalcinoRiserva2010.png'

# %%
    followers = []
following = []
user_ratings = []
for name in tqdm(names):
  # if count % 100 == 0:
  #   print(count)
  # count += 1
  subdf = dft_rev_1[dft_rev_1["image_name"] == "images/" + name]
  if subdf.shape[0] == 0:
    continue
  # num_review.append((name, subdf.num_review.to_list()[0]))
  # float_list = list(map(float, subdf["followers"].to_list()))
  # followers.append(statistics.mean(float_list))
  fol1 = [x for x in subdf["followers"].tolist() if isinstance(x, int)]
  followers.append((name, statistics.mean(fol1) if fol1 else 0))
  # float_list1 = list(map(float, subdf["following"].to_list()))
  fol2 = [x for x in subdf["following"].tolist() if isinstance(x, int)]
  following.append((name, statistics.mean(fol2)if fol2 else 0))
  fol3 = [x for x in subdf["User Ratings"].tolist() if isinstance(x, int)]
  user_ratings.append((name, statistics.mean(fol3) if fol3 else 0))
  # ratings_of_user.append(subdf["User Ratings"].mean())
  # float_list2 = list(map(float, subdf["User Ratings"].to_list()))
  # followers.append(statistics.mean(float_list2))
  # wine_type.append((name,subdf["Wine type"].to_list()[0]))
  # year.append((name,subdf.Year.to_list()[0]))

len(followers)
# Out:
# 100%|██████████| 10394/10394 [1:40:29<00:00,  1.72it/s]
# 6399

# %% [markdown]
# ## Пьемонт

# %%
dfp = pd.read_csv("scaled_features_piemonte.csv")

# %%
# !unzip all_piemonte_wines.zip
# Out:
# Archive:  all_piemonte_wines.zip
#   inflating: all_piemonte_wines.csv

# %%
dfp_rev = pd.read_csv("all_piemonte_wines.csv", sep=";")
dfp_rev.head(2)
# Out:
# <ipython-input-166-98a47ff30e59>:1: DtypeWarning: Columns (10,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfp_rev = pd.read_csv("all_piemonte_wines.csv", sep=";")
#   Winery                   Wine  Rating  num_review Wine type     Wine region  \
# 0    Umi  White Sushi Wine N.V.     3.3          86     White  Italy Piemonte
# 1    Umi  White Sushi Wine N.V.     3.3          86     White  Italy Piemonte
#
#   Country                  Grape  price  \
# 0      it  Sangiovese Chardonnay   3.25
# 1      it  Sangiovese Chardonnay   3.25
#
#                                                 link  ...  Wine ID  \
# 0  https://www.vivino.com/IT/en/umi-white-sushi-w...  ...  3830847
# 1  https://www.vivino.com/IT/en/umi-white-sushi-w...  ...  3830847
#
#    User's Grade                 CreatedAt  user id  followers following  \
# 0           3.5  2017-06-21T12:19:09.000Z  2226059         13        22
# ...

# %%
dfp_rev.shape
# Out:
# (4160193, 21)

# %%
dfp_rev.columns
# Out:
# Index(['Winery', 'Wine', 'Rating', 'num_review', 'Wine type', 'Wine region',
#        'Country', 'Grape', 'price', 'link', 'Year', 'Wine ID', 'User's Grade',
#        'CreatedAt', 'user id', 'followers', 'following', 'User Ratings',
#        'language', 'label', 'image_name'],
#       dtype='object')

# %%
dfp_rev = dfp_rev[["num_review", "Wine type", "Year", "image_name"]]

# %%
dfp_rev.head(2)
# Out:
#    num_review Wine type  Year                     image_name
# 0          86     White  N.V.  images/WhiteSushiWineN.V..png
# 1          86     White  N.V.  images/WhiteSushiWineN.V..png

# %%
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_OpenSans-Light  font_2_Pacifico-Regular  \
# 0                      0                        0
# 1                      0                        0
#
#    font_2_PlayfairDisplay-Regular  font_2_Rakkas-Regular  \
# ...

# %%
names = dfp.image_names

# %%
len(names)
# Out:
# 5933

# %%
num_review = []
wine_type = []
year = []
count = 0
for name in names:
  if count % 100 == 0:
    print(count)
  count += 1
  subdf = dfp_rev[dfp_rev["image_name"] == "images/" + name]
  if subdf.shape[0] == 0:
    continue
  num_review.append((name, subdf.num_review.to_list()[0]))
  # float_list = list(map(float, subdf["followers"].to_list()))
  # followers.append(statistics.mean(float_list))
  # following.append(subdf["following"].mean())
  # float_list1 = list(map(float, subdf["following"].to_list()))
  # following.append(statistics.mean(float_list1))
  # # ratings_of_user.append(subdf["User Ratings"].mean())
  # float_list2 = list(map(float, subdf["User Ratings"].to_list()))
  # followers.append(statistics.mean(float_list2))
  wine_type.append((name,subdf["Wine type"].to_list()[0]))
  year.append((name,subdf.Year.to_list()[0]))

len(num_review)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 5933

# %%
len(num_review)
# Out:
# 5933

# %%
num_review[0]
# Out:
# ('WhiteSushiWineN.V..png', 86)

# %%
len(num_review)
# Out:
# 5933

# %%
len(names)
# Out:
# 5933

# %%
ex_names = []
for n in num_review:
  ex_names.append(n[0])
ex_names[0]
# Out:
# 'WhiteSushiWineN.V..png'

# %%
nums = []
for n in num_review:
  nums.append(n[1])
nums[4]
# Out:
# 16

# %%
amin, amax = min(nums), max(nums)
for i, val in enumerate(nums):
  nums[i] = (val-amin) / (amax-amin)
nums[0]
# Out:
# 0.016494054468738015

# %%
dfp["num_review"] = nums
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_Pacifico-Regular  font_2_PlayfairDisplay-Regular  \
# 0                        0                               0
# 1                        0                               0
#
#    font_2_Rakkas-Regular  font_2_RobotoMono-Regular  \
# ...

# %%
dfp.columns
# Out:
# Index(['Wine', 'link', 'image_names', 'image_link', 'temperature',
#        'saturation', 'brightness', 'contrast', 'clarity', 'colorfulness',
#        'quality', 'rule_of_thirds', 'colour_balance_vert',
#        'colour_balance_hor', 'physical_balance_vert', 'physical_balance_hor',
#        'diagonal_dominance', 'figure_ground_size', 'price', 'rating',
#        'grade_avg', 'font_1_ALfaSlabOne-Regular',
#        'font_1_ArchitectsDaughter-Regular', 'font_1_Arial Black',
#        'font_1_Bangers-Regular', 'font_1_Lora-regular',
#        'font_1_Niconne-Regular', 'font_1_OpenSans-Light',
#        'font_1_PlayfairDisplay-Regular', 'font_1_RobotoMono-Regular',
#        'font_1_SpaceMono-Regular', 'font_1_Times New Roman',
#        'font_1_Times New Roman Italic', 'font_2_ALfaSlabOne-Regular',
#        'font_2_ArchitectsDaughter-Regular', 'font_2_Arial Black',
#        'font_2_Bangers-Regular', 'font_2_Courier', 'font_2_Inter-Regular',
# ...

# %%
wtypes = []
for n in wine_type:
  wtypes.append(n[1])
wtypes[4]
# Out:
# 'Red'

# %%
len(wtypes)
# Out:
# 5933

# %%
dfp["wine_type"] = wtypes
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_PlayfairDisplay-Regular  font_2_Rakkas-Regular  \
# 0                               0                      0
# 1                               0                      0
#
#    font_2_RobotoMono-Regular  font_2_RobotoSlab-Regular  font_2_Rubik-Regular  \
# ...

# %%
dfp1 = pd.get_dummies(dfp.wine_type, prefix='wine_type')
print(dfp1.head(3))
# Out:
#    wine_type_Dessert  wine_type_Fortified  wine_type_Red  wine_type_Rose  \
# 0              False                False          False           False
# 1              False                False          False           False
# 2              False                False          False           False
#
#    wine_type_Sparkling  wine_type_White
# 0                False             True
# 1                 True            False
# 2                False             True

# %%
dfp["wine_type_Dessert"] = dfp1.wine_type_Dessert
dfp["wine_type_Red"] = dfp1.wine_type_Red
dfp["wine_type_Rose"] = dfp1.wine_type_Rose
dfp["wine_type_Sparkling"] = dfp1.wine_type_Sparkling
dfp["wine_type_White"] = dfp1.wine_type_White
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_SpaceMono-Regular  font_2_Times New Roman  \
# 0                         0                       0
# 1                         0                       0
#
#    font_2_Times New Roman Italic  num_review  wine_type  wine_type_Dessert  \
# ...

# %%
dfp = dfp.drop(columns=['wine_type'])
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_Rubik-Regular  font_2_SpaceMono-Regular  font_2_Times New Roman  \
# 0                     0                         0                       0
# 1                     0                         0                       0
#
# ...

# %%
dfp["wine_type_Dessert"] = dfp["wine_type_Dessert"].astype(int)
dfp["wine_type_Red"] = dfp["wine_type_Red"].astype(int)
dfp["wine_type_Rose"] = dfp["wine_type_Rose"].astype(int)
dfp["wine_type_Sparkling"] = dfp["wine_type_Sparkling"].astype(int)
dfp["wine_type_White"] = dfp["wine_type_White"].astype(int)
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_Rubik-Regular  font_2_SpaceMono-Regular  font_2_Times New Roman  \
# 0                     0                         0                       0
# 1                     0                         0                       0
#
# ...

# %%
import math
years = []
for n in year:
  if n[1] != 'N.V.' and not math.isnan(float(n[1])):
    years.append(int(n[1]))
  else:
    years.append(2024)
nums[4]
# Out:
# 0.0030686612965093976

# %%
years[4]
# Out:
# 2022

# %%
min(years)
# Out:
# 1931

# %%
amin, amax = min(years), max(years)
for i, val in enumerate(years):
  years[i] = (val-amin) / (amax-amin)
years[3]
# Out:
# 0.978494623655914

# %%
dfp["year"] = years
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    font_2_SpaceMono-Regular  font_2_Times New Roman  \
# 0                         0                       0
# 1                         0                       0
#
#    font_2_Times New Roman Italic  num_review  wine_type_Dessert  \
# ...

# %%
dfp.to_csv('scaled_features_piemonte.csv', index=False)

# %%
! cp scaled_features_piemonte.csv /content/drive/MyDrive/диплом/scaled_features_piemonte.csv

# %% [markdown]
# ### Данные про отзывы Пьемонта

# %%
dfp_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4160193 entries, 0 to 4160192
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   num_review  int64
#  1   Wine type   object
#  2   Year        object
#  3   image_name  object
# dtypes: int64(1), object(3)
# memory usage: 127.0+ MB

# %%
dfp_rev.head(1)
# Out:
#   Winery                   Wine  Rating  num_review Wine type     Wine region  \
# 0    Umi  White Sushi Wine N.V.     3.3          86     White  Italy Piemonte
#
#   Country                  Grape  price  \
# 0      it  Sangiovese Chardonnay   3.25
#
#                                                 link  ...  Wine ID  \
# 0  https://www.vivino.com/IT/en/umi-white-sushi-w...  ...  3830847
#
#    User's Grade                 CreatedAt  user id  followers following  \
# 0           3.5  2017-06-21T12:19:09.000Z  2226059         13        22
#
#   User Ratings language                      label  \
# 0          237       en  umi-white-sushi-wine-2014
#
#                       image_name
# 0  images/WhiteSushiWineN.V..png
#
# [1 rows x 21 columns]

# %%
len(names)
# Out:
# 5933

# %%
dfp_rev = dfp_rev[["followers", "following", "User Ratings", "image_name"]]

# %%
dfp_rev.head(1)
# Out:
#   followers following User Ratings                     image_name
# 0        13        22          237  images/WhiteSushiWineN.V..png

# %%
from tqdm import tqdm

# %%
import statistics
followers = []
following = []
user_ratings = []
count = 0
for name in tqdm(names):
  # if count % 100 == 0:
  #   print(count)
  # count += 1
  subdf = dfp_rev[dfp_rev["image_name"] == "images/" + name]
  if subdf.shape[0] == 0:
    continue
  # num_review.append((name, subdf.num_review.to_list()[0]))
  # float_list = list(map(float, subdf["followers"].to_list()))
  # followers.append(statistics.mean(float_list))
  fol1 = [x for x in subdf["followers"].tolist() if isinstance(x, int)]
  followers.append(statistics.mean(fol1) if fol1 else 0)
  # float_list1 = list(map(float, subdf["following"].to_list()))
  fol2 = [x for x in subdf["following"].tolist() if isinstance(x, int)]
  following.append(statistics.mean(fol2)if fol2 else 0)
  fol3 = [x for x in subdf["User Ratings"].tolist() if isinstance(x, int)]
  user_ratings.append(statistics.mean(fol3) if fol3 else 0)
  # ratings_of_user.append(subdf["User Ratings"].mean())
  # float_list2 = list(map(float, subdf["User Ratings"].to_list()))
  # followers.append(statistics.mean(float_list2))
  # wine_type.append((name,subdf["Wine type"].to_list()[0]))
  # year.append((name,subdf.Year.to_list()[0]))

len(followers)
# Out:
# 100%|██████████| 5933/5933 [41:16<00:00,  2.40it/s]
# 5933

# %%
set([type(item) for item in user_ratings])
# Out:
# {float, int}

# %%
amin, amax = min(user_ratings), max(user_ratings)
for i, val in enumerate(user_ratings):
 user_ratings[i] = (val-amin) / (amax-amin)
user_ratings[0]
# Out:
# 0.19954795711388007

# %%
dfp["fllowers"] = followers
dfp["following"] = following
dfp["user_ratings"] = user_ratings
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    num_review  wine_type_Dessert  wine_type_Red  wine_type_Rose  \
# 0    0.016494                  0              0               0
# 1    0.083237                  0              0               0
#
# ...

# %%
dfp = dfp.rename(columns={"fllowers": "followers"})
dfp.head(2)
# Out:
#                     Wine                                               link  \
# 0  White Sushi Wine N.V.  https://www.vivino.com/IT/en/umi-white-sushi-w...
# 1         Fragolino N.V.  https://www.vivino.com/IT/en/santero-fragolino...
#
#               image_names                                         image_link  \
# 0  WhiteSushiWineN.V..png  https://images.vivino.com/thumbs/zc1wzl67QkuoJ...
# 1       FragolinoN.V..png  https://images.vivino.com/thumbs/fgUOE94-Tna3g...
#
#    temperature  saturation  brightness  contrast   clarity  colorfulness  ...  \
# 0    -0.606032    1.096150    2.074307  0.260169 -0.204628      1.335462  ...
# 1     1.805028    1.371905   -1.102071  0.260169 -0.692759     -0.599721  ...
#
#    num_review  wine_type_Dessert  wine_type_Red  wine_type_Rose  \
# 0    0.016494                  0              0               0
# 1    0.083237                  0              0               0
#
# ...

# %%
dfp.to_csv('scaled_features_piemonte.csv', index=False)

# %%
! cp scaled_features_piemonte.csv /content/drive/MyDrive/диплом/scaled_features_piemonte.csv
