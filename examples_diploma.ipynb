# %%
import pandas as pd
df = pd.read_csv("image_features.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-195c8da2fa06> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("image_features.csv")
#       3 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.describe()
# Out:
#          temperature    saturation    brightness      contrast       clarity  \
# count   1.039400e+04  10394.000000  10394.000000  10394.000000  10394.000000
# mean   2.415594e+258     65.605412     98.494719      0.989224      0.069087
# std              inf     26.109483     27.770092      0.040413      0.055998
# min     2.912917e+03      0.000000     38.561300      0.036585      0.000256
# 25%     5.623229e+03     45.514109     80.185854      1.000000      0.045176
# 50%     6.427159e+03     59.087270     96.343918      1.000000      0.057144
# 75%     8.883642e+03     79.783184    113.335450      1.000000      0.074175
# max    6.123823e+260    199.997333    240.342500      1.000000      0.854072
#
#        colorfulness
# count  10394.000000
# mean      33.407165
# std       15.778357
# min        0.000000
# 25%       22.619184
# 50%       28.128500
# 75%       38.506175
# max      117.634144

# %%
df.loc[df['temperature'] < 4.0e+03]
# Out:
#                                            Wine  \
# 32                       Tenute del Barone 2009
# 189                      Tenute del Barone 2008
# 708                            Grottascura 2017
# 714                         Poggio al Moro 2015
# 739                      Camponovo Toscana 2021
# 917                             Camalaione 2017
# 1008                            Camalaione 2015
# 1023                     Tenute del Barone 2007
# 1092   Francesco Chiostri Chianti Classico 2018
# 1095   Francesco Chiostri Chianti Classico 2016
# 1127                        Poggio al Moro 2018
# 1147                        Bolgheri Rosso 2017
# 1358                    Cabernet Sauvignon 2013
# 1406                         Fillide Rosso 2010
# 1827          Vino Nobile di Montepulciano 2020
# 2066                           Predicatore 2022
# 2545                                 Aenne 2018
# 2777  Vin Santo del Chianti Rufina Riserva 2011
# ...

# %%
df.loc[df['temperature'] > 6.0e+260]
# Out:
#                 Wine                                               link  \
# 6322  Sassicaia 2006  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6330  Sassicaia 2003  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6347  Sassicaia 2014  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6350  Sassicaia 2012  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6377  Sassicaia 2018  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6453  Sassicaia 2020  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6454  Sassicaia 2019  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6477  Sassicaia 2017  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 6501  Sassicaia 1995  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 8704  Sassicaia 1988  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 8711  Sassicaia 1974  https://www.vivino.com/IT/en/tenuta-san-guido-...
# 8724  Sassicaia 1976  https://www.vivino.com/IT/en/tenuta-san-guido-...
# ...

# %%
df.loc[df['saturation'] < 20]
# Out:
#                                                 Wine  \
# 2151  Poggiarso Gran Selezione Chianti Classico 2018
# 2850                               Poggio Pinzo 2018
# 3691                          Ciliegiolo Rosato 2021
# 4679  Poggiarso Gran Selezione Chianti Classico 2017
# 5446                                   Brendino 2016
# 7137                             9 Code Chianti 2016
# 9109                               Poggio Pinzo 2019
#
#                                                    link  \
# 2151  https://www.vivino.com/IT/en/castello-di-melet...
# 2850  https://www.vivino.com/IT/en/sassotondo-poggio...
# 3691  https://www.vivino.com/IT/en/san-ferdinando-ci...
# 4679  https://www.vivino.com/IT/en/castello-di-melet...
# 5446  https://www.vivino.com/IT/en/cuna-brendino-201...
# 7137  https://www.vivino.com/IT/en/corbucci-nine-cod...
# 9109  https://www.vivino.com/IT/en/sassotondo-poggio...
#
#                                              image_link  \
# ...

# %%
df.loc[df['saturation'] >150]
# Out:
#                                Wine  \
# 214           Pourriture Noble 2009
# 570   Toscana Villa Di Corsano 1999
# 708                Grottascura 2017
# 733            Tramonto Rosato 2021
# 743       Chianti Colli Senesi 2021
# ...                             ...
# 8995             Pomino Bianco 2011
# 9005              Buggea Rosso 2022
# 9033      Chianti Colli Senesi 2021
# 9043                   Mammolo 2007
# 9553          Pomino Vin Santo 1971
#
#                                                    link  \
# 214   https://www.vivino.com/IT/en/fattoria-di-petre...
# 570   https://www.vivino.com/IT/en/cantina-di-montal...
# 708   https://www.vivino.com/IT/en/bagnaia-grottascu...
# 733   https://www.vivino.com/IT/en/ca-di-pesa-tramon...
# 743   https://www.vivino.com/IT/en/it-signano-chiant...
# ...                                                 ...
# 8995  https://www.vivino.com/IT/en/castello-pomino-p...
# 9005  https://www.vivino.com/IT/en/trequanda-buggea-...
# ...

# %%
df.loc[df['brightness'] < 40]
# Out:
#                       Wine                                               link  \
# 5101  Chianti Vecchio 1950  https://www.vivino.com/IT/en/ruffino-chianti-v...
# 8437   Noi 4 Bolgheri 2021  https://www.vivino.com/IT/en/tenuta-dei-sette-...
#
#                                              image_link  \
# 5101  https://images.vivino.com/thumbs/DzvQ7fGhRjajq...
# 8437  https://images.vivino.com/thumbs/kgH8hDtESzGHO...
#
#                  image_names   temperature  saturation  brightness  contrast  \
# 5101  ChiantiVecchio1950.png  5.950090e+83   80.710967   38.561300       1.0
# 8437    Noi4Bolgheri2021.png  3.462660e+03   32.360719   39.623615       1.0
#
#        clarity  colorfulness
# 5101  0.000556     12.301858
# 8437  0.023406     19.106320

# %%
df.loc[df['brightness'] > 200]
# Out:
#                                                 Wine  \
# 1100                     A Solo Maremma Toscana 2006
# 2151  Poggiarso Gran Selezione Chianti Classico 2018
# 2850                               Poggio Pinzo 2018
# 3691                          Ciliegiolo Rosato 2021
# 4679  Poggiarso Gran Selezione Chianti Classico 2017
# 5446                                   Brendino 2016
# 9109                               Poggio Pinzo 2019
#
#                                                    link  \
# 1100  https://www.vivino.com/IT/en/it-tenute-guiccia...
# 2151  https://www.vivino.com/IT/en/castello-di-melet...
# 2850  https://www.vivino.com/IT/en/sassotondo-poggio...
# 3691  https://www.vivino.com/IT/en/san-ferdinando-ci...
# 4679  https://www.vivino.com/IT/en/castello-di-melet...
# 5446  https://www.vivino.com/IT/en/cuna-brendino-201...
# 9109  https://www.vivino.com/IT/en/sassotondo-poggio...
#
#                                              image_link  \
# ...

# %%
df.loc[df['contrast'] < 0.7]
# Out:
#                                                 Wine  \
# 387                             Aurea Gran Rosé 2021
# 2151  Poggiarso Gran Selezione Chianti Classico 2018
# 2850                               Poggio Pinzo 2018
# 3208                            Aurea Gran Rosé 2019
# 3553                              Giardino Rosè 2022
# 3554                              Giardino Rosè 2021
# 3649                      Vivia Maremma Toscana 2020
# 3691                          Ciliegiolo Rosato 2021
# 3814                                 Chardonnay 2022
# 3884                      Vivia Maremma Toscana 2019
# 3939                      Vivia Maremma Toscana 2011
# 3946                      Vivia Maremma Toscana 2018
# 4360                      Vivia Maremma Toscana 2021
# 4387                                 Chardonnay 2022
# 4473                       Aqua di Venus Bianco 2020
# 4679  Poggiarso Gran Selezione Chianti Classico 2017
# 5446                                   Brendino 2016
# ...

# %%
df.loc[df['contrast'] == 1]
# Out:
#                                               Wine  \
# 0                              Bolgheri Rosso 1998
# 1              Brunello di Montalcino Riserva 2010
# 2                  Tenuta Tignanello 'Solaia' 2006
# 3                  Tenuta Tignanello 'Solaia' 1997
# 4                      Brunello di Montalcino 2006
# ...                                            ...
# 10389                  Brunello di Montalcino 1986
# 10390          Brunello di Montalcino Riserva 2004
# 10391          Brunello di Montalcino Riserva 2007
# 10392                  Brunello di Montalcino 2001
# 10393  Massimo Brunello di Montalcino Riserva 2015
#
#                                                     link  \
# 0      https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1      https://www.vivino.com/IT/en/cupano-brunello-d...
# 2      https://www.vivino.com/IT/en/antinori-tuscany-...
# 3      https://www.vivino.com/IT/en/antinori-tuscany-...
# 4      https://www.vivino.com/IT/en/poggio-di-sotto-b...
# ...

# %%
df.loc[df['clarity'] < 0.0003]
# Out:
#                                             Wine  \
# 3459  Vermentino Maremma Toscana Valcolomba 2021
# 3496  Vermentino Maremma Toscana Valcolomba 2022
#
#                                                    link  \
# 3459  https://www.vivino.com/IT/en/carpineto-verment...
# 3496  https://www.vivino.com/IT/en/carpineto-verment...
#
#                                              image_link  \
# 3459  https://images.vivino.com/thumbs/qYtdf2hESXqWw...
# 3496  https://images.vivino.com/thumbs/qYtdf2hESXqWw...
#
#                                      image_names  temperature  saturation  \
# 3459  VermentinoMaremmaToscanaValcolomba2021.png   5435.49638   71.379633
# 3496  VermentinoMaremmaToscanaValcolomba2022.png   5435.49638   71.379633
#
#       brightness  contrast   clarity  colorfulness
# 3459  101.720767  0.915385  0.000256     16.081311
# 3496  101.720767  0.915385  0.000256     16.081311

# %%
df.loc[df['clarity'] > 0.6]
# Out:
#                                     Wine  \
# 1100         A Solo Maremma Toscana 2006
# 1643                        Moscato 2019
# 6645     Brezzarosa Bolgheri Rosato 2021
# 7006      Cerchiaia Chianti Riserva 2016
# 7776     Brezzarosa Bolgheri Rosato 2022
# 8260  Corvallo Costa Toscana Bianco 2022
# 8342                        Moscato 2017
#
#                                                    link  \
# 1100  https://www.vivino.com/IT/en/it-tenute-guiccia...
# 1643  https://www.vivino.com/IT/en/le-anfore-moscato...
# 6645  https://www.vivino.com/IT/en/campo-al-pero-bre...
# 7006  https://www.vivino.com/IT/en/castelfalfi-cerch...
# 7776  https://www.vivino.com/IT/en/campo-al-pero-bre...
# 8260  https://www.vivino.com/IT/en/poggio-al-grillo-...
# 8342  https://www.vivino.com/IT/en/le-anfore-moscato...
#
#                                              image_link  \
# 1100  https://images.vivino.com/wineries/4937/wines/...
# 1643  https://images.vivino.com/thumbs/dnd_wgn6ROeUz...
# ...

# %%
df.loc[df['colorfulness'] < 10]
# Out:
#                                                 Wine  \
# 2151  Poggiarso Gran Selezione Chianti Classico 2018
# 2243                      Vin Santo del Chianti 2016
# 2850                               Poggio Pinzo 2018
# 3352                       Chianti Colli Senesi 2022
# 3535                       Chianti Colli Senesi 2022
# 3691                          Ciliegiolo Rosato 2021
# 3699                      Vin Santo del Chianti 2016
# 4040                       Chianti Colli Senesi 2022
# 4679  Poggiarso Gran Selezione Chianti Classico 2017
# 5446                                   Brendino 2016
# 6721                Toscana Pian di Conte Rosso 1996
# 7006                  Cerchiaia Chianti Riserva 2016
# 7137                             9 Code Chianti 2016
# 9109                               Poggio Pinzo 2019
#
#                                                    link  \
# 2151  https://www.vivino.com/IT/en/castello-di-melet...
# ...

# %%
df.loc[df['colorfulness'] > 100]
# Out:
#                                                    Wine  \
# 570                       Toscana Villa Di Corsano 1999
# 1358                            Cabernet Sauvignon 2013
# 1468                       San Gimignano Vin Santo 2016
# 3368                 La Mora Maremma Toscana Rosso 2020
# 3375                 La Mora Maremma Toscana Rosso 2018
# 3732                                Toscana Rosato 2019
# 3888                   Fuori Misura Toscana Rosato 2019
# 4182                Chardonnay Toscana Le Bruniche 2022
# 4325                   Fuori Misura Toscana Rosato 2020
# 4349                                Ben Vermentino 2022
# 4375                   Fuori Misura Toscana Rosato 2021
# 4421                            Acquagiusta Rosato 2022
# 4424                   Fuori Misura Toscana Rosato 2022
# 6817                                Toscana Rosato 2021
# 6916          Pian delle Vigne Rosso di Montalcino 2020
# 6937                                   Purple Rosé 2019
# ...

# %% [markdown]
# # Конец

# %%
import pandas as pd

# %%
dft = pd.read_csv("scaled_features_tuscany.csv")
dfp = pd.read_csv("scaled_features_piemonte.csv")

# %%
frames = [dft, dfp]
df = pd.concat(frames)

# %%
pd.set_option('display.max_rows', 500)

# %%
pd.set_option('display.max_columns', 500)

# %%
bad_df = df[df["grade_avg"] < 3]

# %%
bad_df.columns
# Out:
# Index(['Wine', 'link', 'image_link', 'image_names', 'temperature',
#        'saturation', 'brightness', 'contrast', 'clarity', 'colorfulness',
#        'quality', 'rule_of_thirds', 'colour_balance_vert',
#        'colour_balance_hor', 'physical_balance_vert', 'physical_balance_hor',
#        'diagonal_dominance', 'figure_ground_size', 'price', 'rating',
#        'grade_avg', 'font_1_ALfaSlabOne-Regular', 'font_1_Arial Black',
#        'font_1_Bangers-Regular', 'font_1_Courier', 'font_1_Lora-regular',
#        'font_1_Niconne-Regular', 'font_1_OpenSans-Light',
#        'font_1_RobotoMono-Regular', 'font_1_SpaceMono-Regular',
#        'font_1_Times New Roman', 'font_1_Times New Roman Italic',
#        'font_2_ALfaSlabOne-Regular', 'font_2_Arial', 'font_2_Arial Black',
#        'font_2_Bangers-Regular', 'font_2_BlackOpsOne-Regular',
#        'font_2_Courier', 'font_2_Inter-Regular', 'font_2_Lora-regular',
#        'font_2_Niconne-Regular', 'font_2_OpenSans-Light',
# ...

# %%
bad_df = bad_df[bad_df["quality"] == 1]

# %%
bad_df[['Wine', 'image_names', 'temperature',
       'saturation', 'brightness', 'contrast', 'clarity', 'colorfulness',
       'quality', 'rule_of_thirds', 'colour_balance_vert',
       'colour_balance_hor', 'physical_balance_vert', 'physical_balance_hor',
       'diagonal_dominance', 'figure_ground_size', 'price', 'rating',
       'grade_avg']]
# Out:
#                                                    Wine  \
# 8992                          Gran Sigillo Toscana 2013
# 9017                          Gran Sigillo Toscana 2016
# 11                        Saraceno Dolcetto d'Alba 2022
# 15                                 Langhe Dolcetto 2021
# 29                         Navirot Dolcetto d'Alba 2022
# 54             Terre dei Roggeri Grignolino d'Asti 2022
# 138               Barbera del Monferrato Frizzante 2021
# 271                          9.5.8 Cuvée Extra Dry 2021
# 720   Sorì del Montagrillo Dolcetto di Diano d'Alba ...
#
#                                           image_names  temperature  \
# 8992                       GranSigilloToscana2013.png     1.750861
# 9017                       GranSigilloToscana2016.png     1.750861
# 11                     SaracenoDolcettod'Alba2022.png    -0.533490
# 15                             LangheDolcetto2021.png    -0.497212
# ...

# %%
good_df = df[df["grade_avg"] > 4.5]

# %%
good_df = good_df[good_df["price"] < 50]

# %%
good_df = good_df[good_df["quality"] == 1]

# %%
good_df[['Wine', 'image_names', 'temperature',
       'saturation', 'brightness', 'contrast', 'clarity', 'colorfulness',
       'quality', 'rule_of_thirds', 'colour_balance_vert',
       'colour_balance_hor', 'physical_balance_vert', 'physical_balance_hor',
       'diagonal_dominance', 'figure_ground_size', 'price', 'rating',
       'grade_avg']]
# Out:
#                                              Wine  \
# 341                    Il Passito di Corzano 2019
# 391                  Vin Santo di Carmignano 2010
# 928                    Il Passito di Corzano 2006
# 2779                                 Fedardo 2011
# 2794                   Il Passito di Corzano 2015
# 8418                      Ansonica dell'Elba 2019
# 9110                              Numero Sei 2020
# 9387  La Mandria del Pari Cabernet Sauvignon 2018
# 9419  La Mandria del Pari Cabernet Sauvignon 2016
#
#                                     image_names  temperature  saturation  \
# 341                  IlPassitodiCorzano2019.png    -0.625991    1.613434
# 391                VinSantodiCarmignano2010.png    -0.655892    1.637862
# 928                  IlPassitodiCorzano2006.png    -0.625991    1.613434
# 2779                            Fedardo2011.png    -0.689563    3.135585
# 2794                 IlPassitodiCorzano2015.png    -0.625991    1.613434
# ...

# %%
good_df = good_df[good_df["temperature"] < -0.5]

# %%
good_df
# Out:
#                                              Wine  \
# 341                    Il Passito di Corzano 2019
# 391                  Vin Santo di Carmignano 2010
# 747      Poggio Teo Chianti Classico Riserva 2019
# 928                    Il Passito di Corzano 2006
# 2779                                 Fedardo 2011
# 2794                   Il Passito di Corzano 2015
# 8418                      Ansonica dell'Elba 2019
# 8439                           Toscana Rosso 2019
# 8787                           Toscana Rosso 2019
# 9110                              Numero Sei 2020
# 9387  La Mandria del Pari Cabernet Sauvignon 2018
# 9419  La Mandria del Pari Cabernet Sauvignon 2016
# 1635                              Nizza DOCG 2019
#
#                                                    link  \
# 341   https://www.vivino.com/IT/en/fattoria-corzano-...
# 391   https://www.vivino.com/IT/en/bacchereto-vin-sa...
# 747   https://www.vivino.com/IT/en/valiano-poggio-te...
# ...

# %%
from IPython.display import Image
Image("/content/TerredeiRoggeriGrignolinod'Asti2022.png")

# %%
Image("/content/9.5.8CuvéeExtraDry2021.png")

# %%
Image("/content/LaMandriadelPariCabernetSauvignon2016.png")

# %%
Image("/content/NumeroSei2020.png")

# %%
df[df.image_names == "LaMandriadelPariCabernetSauvignon2016.png"]
# Out:
#                                              Wine  \
# 9419  La Mandria del Pari Cabernet Sauvignon 2016
#
#                                                    link  \
# 9419  https://www.vivino.com/IT/en/cantine-russo-la-...
#
#                                              image_link  \
# 9419  https://images.vivino.com/thumbs/YoPEXQTkTiCtT...
#
#                                     image_names  temperature  saturation  \
# 9419  LaMandriadelPariCabernetSauvignon2016.png    -0.546962   -0.541173
#
#       brightness  contrast   clarity  colorfulness  quality  rule_of_thirds  \
# 9419    0.921734  0.266658  0.239917      0.961757        1       -0.180071
#
#       colour_balance_vert  colour_balance_hor  physical_balance_vert  \
# 9419            -0.090568            0.707409              -0.454046
#
#       physical_balance_hor  diagonal_dominance  figure_ground_size  price  \
# 9419             -0.741442            0.219849            1.225219   41.7
#
# ...

# %%
df[df.image_names == "NumeroSei2020.png"]
# Out:
#                  Wine                                               link  \
# 9110  Numero Sei 2020  https://www.vivino.com/IT/en/sassotondo-ranze-...
#
#                                              image_link        image_names  \
# 9110  https://images.vivino.com/thumbs/KSzutyf4Q0GCm...  NumeroSei2020.png
#
#       temperature  saturation  brightness  contrast   clarity  colorfulness  \
# 9110    -0.556087    1.575174   -1.232566 -0.154543 -0.191319     -0.812115
#
#       quality  rule_of_thirds  colour_balance_vert  colour_balance_hor  \
# 9110        1       -0.179707            -0.731118             0.02008
#
#       physical_balance_vert  physical_balance_hor  diagonal_dominance  \
# 9110               0.500085              3.399446           -0.180965
#
#       figure_ground_size  price  rating  grade_avg  \
# 9110           -2.015852  41.78     0.0   4.664286
#
#       font_1_ALfaSlabOne-Regular  font_1_Arial Black  font_1_Bangers-Regular  \
# ...

# %%
df[df.Wine == "9.5.8 Cuvée Extra Dry 2021"]
# Out:
#                            Wine  \
# 271  9.5.8 Cuvée Extra Dry 2021
#
#                                                   link  \
# 271  https://www.vivino.com/IT/en/santero-cuvee-ext...
#
#                                             image_link  \
# 271  https://images.vivino.com/thumbs/SZvMAiXbQTC9j...
#
#                     image_names  temperature  saturation  brightness  \
# 271  9.5.8CuvéeExtraDry2021.png    -0.481785   -0.166049    3.013468
#
#      contrast   clarity  colorfulness  quality  rule_of_thirds  \
# 271  0.089001 -0.383428      0.072246        1         0.33708
#
#      colour_balance_vert  colour_balance_hor  physical_balance_vert  \
# 271            -0.569505            1.312084              -0.190178
#
#      physical_balance_hor  diagonal_dominance  figure_ground_size  price  \
# 271             -0.777843             0.02067           -1.723247   10.5
#
#      rating  grade_avg  font_1_ALfaSlabOne-Regular  font_1_Arial Black  \
# ...

# %%
df[df.image_names == "TerredeiRoggeriGrignolinod'Asti2022.png"]
# Out:
#                                         Wine  \
# 54  Terre dei Roggeri Grignolino d'Asti 2022
#
#                                                  link  \
# 54  https://www.vivino.com/IT/en/castagnole-monfer...
#
#                                            image_link  \
# 54  https://images.vivino.com/thumbs/oJgV8u3YRe-xz...
#
#                                 image_names  temperature  saturation  \
# 54  TerredeiRoggeriGrignolinod'Asti2022.png    -0.492464   -0.239158
#
#     brightness  contrast   clarity  colorfulness  quality  rule_of_thirds  \
# 54    0.583094  0.260169 -0.045857     -0.187703        1       -0.183318
#
#     colour_balance_vert  colour_balance_hor  physical_balance_vert  \
# 54            -1.321956            0.316814               1.748681
#
#     physical_balance_hor  diagonal_dominance  figure_ground_size  price  \
# 54             -0.248995            0.217767           -0.663302    8.0
#
# ...

# %%
tuscany.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("scaled_features_tuscany.csv")

# %%
pd.set_option('display.max_columns', 100)

# %%
df.head(10)
# Out:
#                                                 Wine  \
# 0                                Bolgheri Rosso 1998
# 1                Brunello di Montalcino Riserva 2010
# 2                    Tenuta Tignanello 'Solaia' 2006
# 3                    Tenuta Tignanello 'Solaia' 1997
# 4                        Brunello di Montalcino 2006
# 5             Cerretalto Brunello di Montalcino 2007
# 6  Riserva Ducale Oro Chianti Classico (Gran Sele...
# 7                        Brunello di Montalcino 2018
# 8                       Schidione lll Millennio 1997
# 9                                Migliara Syrah 2006
#
#                                                 link  \
# 0  https://www.vivino.com/IT/en/le-macchiole-bolg...
# 1  https://www.vivino.com/IT/en/cupano-brunello-d...
# 2  https://www.vivino.com/IT/en/antinori-tuscany-...
# 3  https://www.vivino.com/IT/en/antinori-tuscany-...
# 4  https://www.vivino.com/IT/en/poggio-di-sotto-b...
# 5  https://www.vivino.com/IT/en/casanova-di-neri-...
# ...

# %%
! unzip xaa.zip
# Out:
# Archive:  xaa.zip
#   inflating: xaa.csv

# %%
dfr = pd.read_csv("xaa.csv", sep = ";")
# Out:
# <ipython-input-16-b1d1633252ab>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfr = pd.read_csv("xaa.csv", sep = ";")

# %%
dfr.tail(100)
# Out:
#                    Winery                    Wine  Rating  num_review  \
# 711987  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711988  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711989  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711990  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711991  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711992  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711993  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711994  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711995  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711996  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711997  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# 711998  Tenuta di Nozzole  Toscana Il Pareto 2003     4.3        51.0
# ...

# %%
dfr.link.to_list()[-1]
# Out:
# 'https://www.vivino.com/IT/en/tenuta-di-nozzole-toscana-il-pareto-2003/w/1100318'

# %%
dfr.link[0]
# Out:
# 'https://www.vivino.com/IT/en/le-macchiole-bolgheri-rosso-1998/w/16417'

# %%
df[df["image_names"] == "Ca'MarcandaBolgheri2013.png"].link.to_list()
# Out:
# ['https://www.vivino.com/IT/en/gaja-ca-marcanda-bolgheri-2013/w/1724156']

# %%
df[df["image_names"] == "CampomaccioneRosato2019.png"]
# Out:
#                            Wine  \
# 3334  Campomaccione Rosato 2019
#
#                                                    link  \
# 3334  https://www.vivino.com/IT/en/rocca-delle-macie...
#
#                                              image_link  \
# 3334  https://images.vivino.com/thumbs/m9zy0pB2Si22n...
#
#                       image_names  temperature  saturation  brightness  \
# 3334  CampomaccioneRosato2019.png    -0.557132    0.331221    3.068035
#
#       contrast  clarity  colorfulness  ...  wine_type_White      year  \
# 3334 -3.526461 -0.09009      1.233537  ...                0  0.936709
#
#       followers  following  user_ratings  rating2020  rating2021  rating2022  \
# 3334   0.007884   0.001561      0.174262    3.571429    3.630435    3.573077
#
#       rating2023  rating2024
# 3334    3.542857    3.542857
#
# [1 rows x 68 columns]

# %%
df[df["image_names"] == "CampomaccioneRosato2019.png"].link.to_list()
# Out:
# ['https://www.vivino.com/IT/en/rocca-delle-macie-campomaccione-rosato-tuscany-2019/w/5275931']
